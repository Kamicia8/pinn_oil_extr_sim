# %% [markdown]
# # Cahn-Hilliard equation
#
# ```{admonition} Download sources
# :class: download
# * {download}`Python script <./demo_cahn-hilliard.py>`
# * {download}`Jupyter notebook <./demo_cahn-hilliard.ipynb>`
# ```
# This example demonstrates the solution of the Cahn-Hilliard equation,
# a nonlinear, time-dependent fourth-order PDE.
#
# - A mixed finite element method
# - The $\theta$-method for time-dependent equations
# - Automatic linearisation
# - Use of the class
#   {py:class}`NonlinearProblem<dolfinx.fem.petsc.NonlinearProblem>`
# - Interpolation of functions
# - Visualisation of a running simulation with
#   [PyVista](https://pyvista.org/)
#
# ## Equation and problem definition
#
# The Cahn-Hilliard equation is a parabolic equation and is typically
# used to model phase separation in binary mixtures.  It involves
# first-order time derivatives, and second- and fourth-order spatial
# derivatives.  The equation reads:
#
# $$
# \begin{align}
# \frac{\partial c}{\partial t} -
#   \nabla \cdot M \left(\nabla\left(\frac{d f}{dc}
#   - \lambda \nabla^{2}c\right)\right) &= 0 \quad {\rm in} \ \Omega, \\
# M\left(\nabla\left(\frac{d f}{d c} -
#   \lambda \nabla^{2}c\right)\right) \cdot n
#   &= 0 \quad {\rm on} \ \partial\Omega, \\
# M \lambda \nabla c \cdot n &= 0 \quad {\rm on} \ \partial\Omega.
# \end{align}
# $$
#
# where $c$ is the unknown field, the function $f$ is usually non-convex
# in $c$ (a fourth-order polynomial is commonly used), $n$ is the
# outward directed boundary normal, and $M$ is a scalar parameter.
#
# ### Operator split form
#
# The Cahn-Hilliard equation is a fourth-order equation, so casting it
# in a weak form would result in the presence of second-order spatial
# derivatives, and the problem could not be solved using a standard
# Lagrange finite element basis.  A solution is to rephrase the problem
# as two coupled second-order equations:
#
# $$
# \begin{align}
# \frac{\partial c}{\partial t} - \nabla \cdot M \nabla\mu
#     &= 0 \quad {\rm in} \ \Omega, \\
# \mu -  \frac{d f}{d c} + \lambda \nabla^{2}c &= 0 \quad {\rm in}
#   \ \Omega.
# \end{align}
# $$
#
# The unknown fields are now $c$ and $\mu$. The weak (variational) form
# of the problem reads: find $(c, \mu) \in V \times V$ such that
#
# $$
# \begin{align}
# \int_{\Omega} \frac{\partial c}{\partial t} q \, {\rm d} x +
#     \int_{\Omega} M \nabla\mu \cdot \nabla q \, {\rm d} x
#     &= 0 \quad \forall \ q \in V,  \\
# \int_{\Omega} \mu v \, {\rm d} x - \int_{\Omega} \frac{d f}{d c} v \,
#   {\rm d} x - \int_{\Omega} \lambda \nabla c \cdot \nabla v \, {\rm d} x
#    &= 0 \quad \forall \ v \in V.
# \end{align}
# $$
#
# ### Time discretisation
#
# Before being able to solve this problem, the time derivative must be
# dealt with. Apply the $\theta$-method to the mixed weak form of the
# equation:
#
# $$
# \begin{align}
# \int_{\Omega} \frac{c_{n+1} - c_{n}}{dt} q \, {\rm d} x
#   + \int_{\Omega} M \nabla \mu_{n+\theta} \cdot \nabla q \, {\rm d} x
#   &= 0 \quad \forall \ q \in V  \\
# \int_{\Omega} \mu_{n+1} v  \, {\rm d} x - \int_{\Omega}
#   \frac{d f_{n+1}}{d c} v  \, {\rm d} x - \int_{\Omega} \lambda \nabla
#   c_{n+1} \cdot \nabla v \, {\rm d} x &= 0 \quad \forall \ v \in V
# \end{align}
# $$
#
# where $dt = t_{n+1} - t_{n}$ and $\mu_{n+\theta} = (1-\theta) \mu_{n} +
# \theta \mu_{n+1}$.
# The task is: given $c_{n}$ and $\mu_{n}$, solve the above equation to
# find $c_{n+1}$ and $\mu_{n+1}$.
#
# ### Demo parameters
#
# The following domains, functions and time stepping parameters are used
# in this demo:
#
# - $\Omega = (0, 1) \times (0, 1)$ (unit square)
# - $f = 100 c^{2} (1-c)^{2}$
# - $\lambda = 1 \times 10^{-2}$
# - $M = 1$
# - $dt = 5 \times 10^{-6}$
# - $\theta = 0.5$
#
# ## Implementation

# %%
import os
from pathlib import Path

from mpi4py import MPI
from petsc4py import PETSc

import numpy as np

import ufl
from basix.ufl import element, mixed_element
from dolfinx import default_real_type, log, plot
from dolfinx.fem import Function, functionspace
from dolfinx.fem.petsc import NonlinearProblem
from dolfinx.io import XDMFFile
from dolfinx.mesh import CellType, create_unit_square

try:
    import pyvista as pv
    import pyvistaqt as pvqt

    have_pyvista = True
except ModuleNotFoundError:
    print("pyvista and pyvistaqt are required to visualise the solution")
    have_pyvista = False


# Save all logging to file
log.set_output_file("log.txt")

# %% [markdown]
# Next, various model parameters are defined:

# %%
lmbda = 1.0e-02  # surface parameter
dt = 5.0e-06  # time step
theta = 0.5  # time stepping family, e.g. theta=1 -> backward Euler, theta=0.5 -> Crank-Nicholson
t = 0.0  # Current time

# %% [markdown]
# A unit square mesh with 96 cells edges in each direction is created,
# and on this mesh a
# {py:class}`FunctionSpace <dolfinx.fem.FunctionSpace>` `ME` is built
# using a pair of linear Lagrange elements.

# %%
msh = create_unit_square(MPI.COMM_WORLD, 96, 96, CellType.triangle)
P1 = element("Lagrange", msh.basix_cell(), 1, dtype=default_real_type)
ME = functionspace(msh, mixed_element([P1, P1]))

# %% [markdown]
# Trial and test functions of the space `ME` are now defined:

# %%
q, v = ufl.TestFunctions(ME)

# %% [markdown]
# ```{index} split functions
# ```
#
# For the test functions, {py:func}`TestFunctions<function
# ufl.argument.TestFunctions>` (note the 's' at the end) is used to
# define the scalar test functions `q` and `v`. Some mixed objects of
# the {py:class}`Function<dolfinx.fem.function.Function>` class on `ME`
# are defined to represent $u = (c_{n+1}, \mu_{n+1})$ and $u0 = (c_{n},
# \mu_{n})$, and these are then split into sub-functions:

# %%
u = Function(ME)  # current solution
u0 = Function(ME)  # solution from previous converged step

# Split mixed functions
c, mu = ufl.split(u)
c0, mu0 = ufl.split(u0)

# %% [markdown]
# The line `c, mu = split(u)` permits direct access to the
# components of a mixed function. Note that `c` and `mu` are references
# for components of `u`, and not copies.
#
# ```{index} single: interpolating functions; (in Cahn-Hilliard demo)
# ```
#
# The initial conditions are interpolated into a finite element space:

# %%
# Interpolate initial condition
rng = np.random.default_rng(42)
u.sub(0).interpolate(lambda x: 0.63 + 0.02 * (0.5 - rng.random(x.shape[1])))
u.x.scatter_forward()

# %% [markdown]
# The first line creates an object of type `InitialConditions`.  The
# following two lines make `u` and `u0` interpolants of `u_init` (since
# `u` and `u0` are finite element functions, they may not be able to
# represent a given function exactly, but the function can be
# approximated by interpolating it in a finite element space).
#
# ```{index} automatic differentiation
# ```
#
# The chemical potential $df/dc$ is computed using UFL automatic
# differentiation:

# %%
# Compute the chemical potential df/dc
c = ufl.variable(c)
f = 100 * c**2 * (1 - c) ** 2
dfdc = ufl.diff(f, c)

# %% [markdown]
# The first line declares that `c` is a variable that some function can
# be differentiated with respect to. The next line is the function $f$
# defined in the problem statement, and the third line performs the
# differentiation of `f` with respect to the variable `c`.
#
# It is convenient to introduce an expression for $\mu_{n+\theta}$:

# %%
mu_mid = (1.0 - theta) * mu0 + theta * mu  # mu_(n+theta)

# %% [markdown]
# which is then used in the definition of the variational forms:

# %%
# Weak statement of the equations
F0 = (
    ufl.inner(c, q) * ufl.dx
    - ufl.inner(c0, q) * ufl.dx
    + dt * ufl.inner(ufl.grad(mu_mid), ufl.grad(q)) * ufl.dx
)
F1 = (
    ufl.inner(mu, v) * ufl.dx
    - ufl.inner(dfdc, v) * ufl.dx
    - lmbda * ufl.inner(ufl.grad(c), ufl.grad(v)) * ufl.dx
)
F = F0 + F1

# %% [markdown]
# This is a statement of the time-discrete equations presented as part
# of the problem statement, using UFL syntax.
#
# ```{index} single: Newton solver; (in Cahn-Hilliard demo)
# ```
#
# To solve the nonlinear system of equations,
# {py:class}`NonlinearProblem<dolfinx.fem.petsc.NonlinearProblem>` object
# to solve a system of nonlinear equations.
# For the factorisation of the underlying linearized problems, prefer
# MUMPS, then superlu_dist, then default.
# We measure convergence by looking at the norm of the increment of the
# solution between two iterations, called `stol` in PETSc, see:
# [`SNES convegence tests`](https://petsc.org/release/manual/snes/#convergence-tests)
# for further details.

# %%
use_superlu = PETSc.IntType == np.int64  # or PETSc.ScalarType == np.complex64
sys = PETSc.Sys()  # type: ignore
if sys.hasExternalPackage("mumps") and not use_superlu:
    linear_solver = "mumps"
elif sys.hasExternalPackage("superlu_dist"):
    linear_solver = "superlu_dist"
else:
    linear_solver = "petsc"
petsc_options = {
    "snes_type": "newtonls",
    "snes_linesearch_type": "none",
    "snes_stol": np.sqrt(np.finfo(default_real_type).eps) * 1e-2,
    "snes_atol": 0,
    "snes_rtol": 0,
    "ksp_type": "preonly",
    "pc_type": "lu",
    "pc_factor_mat_solver_type": linear_solver,
    "snes_monitor": None,
}
problem = NonlinearProblem(
    F, u, petsc_options_prefix="demo_cahn-hilliard_", petsc_options=petsc_options
)

# %% [markdown]
# We prepare output files and pyvista for time-dependent visualization:

# %%
out_folder = Path("demo_ch")
out_folder.mkdir(parents=True, exist_ok=True)
file = XDMFFile(MPI.COMM_WORLD, out_folder / "output.xdmf", "w")  # Output file
file.write_mesh(msh)

# %% [markdown]
# Get the sub-space for c and the corresponding dofs in the mixed space
# vector. This is used for visualization on the collapsed subspace with
# pyvista.

# %%
V0, dofs = ME.sub(0).collapse()

# %% [markdown]
# Prepare viewer for plotting the solution during the computation

# %%
if have_pyvista:
    # Create a VTK 'mesh' with 'nodes' at the function dofs
    topology, cell_types, x = plot.vtk_mesh(V0)
    grid = pv.UnstructuredGrid(topology, cell_types, x)

    # Set output data
    grid.point_data["c"] = u.x.array[dofs].real
    grid.set_active_scalars("c")

    p = pvqt.BackgroundPlotter(title="concentration", auto_update=True)
    p.add_mesh(grid, clim=[0, 1])
    p.view_xy(negative=True)
    p.add_text(f"time: {t}", font_size=12, name="timelabel")

# %%
# Reduce run time if on test (CI) server
if "CI" in os.environ.keys() or "GITHUB_ACTIONS" in os.environ.keys():
    T = 3 * dt
else:
    T = 50 * dt

# %% [markdown]
# The solver is advanced in time from $t_{n}$ to
# $t_{n+1}$ until a terminal time $T$ is reached

# %%
c = u.sub(0)
u0.x.array[:] = u.x.array
step = 0
while t < T:
    t += dt
    _ = problem.solve()
    converged_reason = problem.solver.getConvergedReason()
    assert converged_reason > 0
    num_iterations = problem.solver.getIterationNumber()
    print(f"Step {step}: {converged_reason=} {num_iterations=}")
    u0.x.array[:] = u.x.array
    file.write_function(c, t)

    # Flushing the output ensures that the full output is written to the
    # disk.
    file.flush()
    step += 1

    # Update the plot window
    if have_pyvista:
        p.add_text(f"time: {t:.2e}", font_size=12, name="timelabel")
        grid.point_data["c"] = u.x.array[dofs].real
        p.app.processEvents()

file.close()
# Out:
#   0 SNES Function norm 1.275680614466e-01
#   1 SNES Function norm 2.635024323703e-05
#   2 SNES Function norm 4.238561925973e-10
#   3 SNES Function norm 1.280671451704e-16
#   4 SNES Function norm 1.271840081051e-16
# Step 0: converged_reason=4 num_iterations=4
#   0 SNES Function norm 5.413271761860e-05
#   1 SNES Function norm 1.316505926148e-05
#   2 SNES Function norm 7.879227831344e-10
#   3 SNES Function norm 1.290843170627e-16
#   4 SNES Function norm 1.274825072719e-16
# Step 1: converged_reason=4 num_iterations=4
#   0 SNES Function norm 5.610422844477e-05
#   1 SNES Function norm 5.744688339499e-05
#   2 SNES Function norm 1.555553749341e-08
#   3 SNES Function norm 2.592456050669e-15
#   4 SNES Function norm 1.295174320916e-16
# Step 2: converged_reason=4 num_iterations=4
#   0 SNES Function norm 7.779469195948e-05
#   1 SNES Function norm 2.696491175757e-04
#   2 SNES Function norm 2.958487326851e-07
#   3 SNES Function norm 1.028106536446e-12
#   4 SNES Function norm 1.273208148247e-16
# Step 3: converged_reason=4 num_iterations=4
#   0 SNES Function norm 1.474750989050e-04
#   1 SNES Function norm 1.199825492072e-03
#   2 SNES Function norm 4.421174669477e-06
#   3 SNES Function norm 2.743787742682e-10
#   4 SNES Function norm 1.286416205216e-16
#   5 SNES Function norm 1.271049519496e-16
# Step 4: converged_reason=4 num_iterations=5
#   0 SNES Function norm 3.265521083312e-04
#   1 SNES Function norm 7.285185002950e-03
#   2 SNES Function norm 5.752654015237e-04
#   3 SNES Function norm 9.345036231549e-06
#   4 SNES Function norm 3.516110293761e-09
#   5 SNES Function norm 6.063332559069e-16
#   6 SNES Function norm 1.260357892772e-16
# Step 5: converged_reason=4 num_iterations=6
#   0 SNES Function norm 6.851395198394e-04
#   1 SNES Function norm 3.845538783222e-02
#   2 SNES Function norm 4.783957506286e-03
#   3 SNES Function norm 1.291782981788e-04
#   4 SNES Function norm 1.187697350019e-07
#   5 SNES Function norm 1.275336691087e-13
#   6 SNES Function norm 1.252732281378e-16
# Step 6: converged_reason=4 num_iterations=6
#   0 SNES Function norm 9.044714811908e-04
#   1 SNES Function norm 3.995644229250e-02
#   2 SNES Function norm 3.844395724873e-03
#   3 SNES Function norm 8.233472330511e-05
#   4 SNES Function norm 7.715324025967e-08
#   5 SNES Function norm 1.183428366285e-13
#   6 SNES Function norm 1.270210432561e-16
# Step 7: converged_reason=4 num_iterations=6
#   0 SNES Function norm 6.606607618007e-04
#   1 SNES Function norm 1.987777532668e-02
#   2 SNES Function norm 1.875968861085e-03
#   3 SNES Function norm 7.160792375821e-05
#   4 SNES Function norm 1.629807001588e-07
#   5 SNES Function norm 8.631605804959e-13
#   6 SNES Function norm 1.286664141059e-16
# Step 8: converged_reason=4 num_iterations=6
#   0 SNES Function norm 4.524585004104e-04
#   1 SNES Function norm 1.051911041765e-02
#   2 SNES Function norm 5.321169366423e-04
#   3 SNES Function norm 3.503190711674e-06
#   4 SNES Function norm 2.922467375066e-10
#   5 SNES Function norm 1.302105963722e-16
#   6 SNES Function norm 1.278722810728e-16
# Step 9: converged_reason=4 num_iterations=6
#   0 SNES Function norm 3.999345945295e-04
#   1 SNES Function norm 9.321462169244e-03
#   2 SNES Function norm 5.505048107478e-04
#   3 SNES Function norm 8.323218657282e-06
#   4 SNES Function norm 5.161596702724e-09
#   5 SNES Function norm 2.239709216405e-15
#   6 SNES Function norm 1.277003363392e-16
# Step 10: converged_reason=4 num_iterations=6
#   0 SNES Function norm 3.485639495337e-04
#   1 SNES Function norm 6.238880972490e-03
#   2 SNES Function norm 2.151660165661e-04
#   3 SNES Function norm 7.676209225525e-07
#   4 SNES Function norm 1.512067568537e-11
#   5 SNES Function norm 1.311289509546e-16
# Step 11: converged_reason=4 num_iterations=5
#   0 SNES Function norm 3.046718918095e-04
#   1 SNES Function norm 4.535546140556e-03
#   2 SNES Function norm 1.115293105455e-04
#   3 SNES Function norm 3.940787951872e-07
#   4 SNES Function norm 1.043152533943e-11
#   5 SNES Function norm 1.310016477893e-16
#   6 SNES Function norm 1.282258158817e-16
# Step 12: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.778310893816e-04
#   1 SNES Function norm 5.731735212085e-03
#   2 SNES Function norm 4.911072970586e-04
#   3 SNES Function norm 8.845752402926e-06
#   4 SNES Function norm 3.183989900517e-09
#   5 SNES Function norm 4.381531004328e-16
#   6 SNES Function norm 1.272348379632e-16
# Step 13: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.470114542370e-04
#   1 SNES Function norm 3.606620992307e-03
#   2 SNES Function norm 1.294108755703e-04
#   3 SNES Function norm 5.077015807984e-07
#   4 SNES Function norm 9.380059966169e-12
#   5 SNES Function norm 1.299992862137e-16
# Step 14: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.352782633509e-04
#   1 SNES Function norm 3.421119558516e-03
#   2 SNES Function norm 8.391003128452e-05
#   3 SNES Function norm 1.196294061998e-07
#   4 SNES Function norm 2.947478589279e-13
#   5 SNES Function norm 1.285608728965e-16
# Step 15: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.382847646655e-04
#   1 SNES Function norm 4.879530761251e-03
#   2 SNES Function norm 2.726070828195e-04
#   3 SNES Function norm 1.875912074175e-06
#   4 SNES Function norm 1.150960695756e-10
#   5 SNES Function norm 1.296087437964e-16
#   6 SNES Function norm 1.287736911624e-16
# Step 16: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.318704761183e-04
#   1 SNES Function norm 3.873496546827e-03
#   2 SNES Function norm 1.322681546620e-04
#   3 SNES Function norm 3.635260578188e-07
#   4 SNES Function norm 4.135409226449e-12
#   5 SNES Function norm 1.297276144520e-16
# Step 17: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.192307238300e-04
#   1 SNES Function norm 2.716810870075e-03
#   2 SNES Function norm 4.916361098874e-05
#   3 SNES Function norm 4.754097311262e-08
#   4 SNES Function norm 5.990254490405e-14
#   5 SNES Function norm 1.294493855544e-16
# Step 18: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.134153081605e-04
#   1 SNES Function norm 2.572066164571e-03
#   2 SNES Function norm 5.835426062934e-05
#   3 SNES Function norm 1.013188891858e-07
#   4 SNES Function norm 3.926776297435e-13
#   5 SNES Function norm 1.296521195086e-16
# Step 19: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.128137985297e-04
#   1 SNES Function norm 2.540509485346e-03
#   2 SNES Function norm 4.968446222270e-05
#   3 SNES Function norm 6.046808609236e-08
#   4 SNES Function norm 1.076584495998e-13
#   5 SNES Function norm 1.290856490732e-16
# Step 20: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.156760879463e-04
#   1 SNES Function norm 2.600299648632e-03
#   2 SNES Function norm 5.200105858127e-05
#   3 SNES Function norm 7.448666481805e-08
#   4 SNES Function norm 2.057579758393e-13
#   5 SNES Function norm 1.292538659836e-16
# Step 21: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.232928101895e-04
#   1 SNES Function norm 2.880460341454e-03
#   2 SNES Function norm 6.054176472565e-05
#   3 SNES Function norm 7.162003134964e-08
#   4 SNES Function norm 2.105554981477e-13
#   5 SNES Function norm 1.313079877369e-16
# Step 22: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.454862334317e-04
#   1 SNES Function norm 4.837848575958e-03
#   2 SNES Function norm 2.346333527206e-04
#   3 SNES Function norm 1.998815968425e-06
#   4 SNES Function norm 2.128973104882e-10
#   5 SNES Function norm 1.305471256588e-16
#   6 SNES Function norm 1.295033117961e-16
# Step 23: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.796300664028e-04
#   1 SNES Function norm 1.184681837265e-02
#   2 SNES Function norm 1.235357551788e-03
#   3 SNES Function norm 2.701983613278e-05
#   4 SNES Function norm 1.749550231809e-08
#   5 SNES Function norm 8.349011740082e-15
#   6 SNES Function norm 1.281222769535e-16
# Step 24: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.488444264616e-04
#   1 SNES Function norm 4.036457223251e-03
#   2 SNES Function norm 1.096046538149e-04
#   3 SNES Function norm 1.903092275692e-07
#   4 SNES Function norm 6.905668360007e-13
#   5 SNES Function norm 1.288780889811e-16
# Step 25: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.304085248738e-04
#   1 SNES Function norm 3.930002558606e-03
#   2 SNES Function norm 1.834669205554e-04
#   3 SNES Function norm 1.199597597812e-06
#   4 SNES Function norm 7.720833079436e-11
#   5 SNES Function norm 1.311940620512e-16
#   6 SNES Function norm 1.289897968561e-16
# Step 26: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.322031149156e-04
#   1 SNES Function norm 4.624459963215e-03
#   2 SNES Function norm 2.341593451946e-04
#   3 SNES Function norm 1.436179805094e-06
#   4 SNES Function norm 6.666649433648e-11
#   5 SNES Function norm 1.330096943405e-16
#   6 SNES Function norm 1.309680816537e-16
# Step 27: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.284179206848e-04
#   1 SNES Function norm 3.043051509885e-03
#   2 SNES Function norm 5.549461142106e-05
#   3 SNES Function norm 4.739261663655e-08
#   4 SNES Function norm 4.629068166100e-14
#   5 SNES Function norm 1.289628029065e-16
# Step 28: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.261221645151e-04
#   1 SNES Function norm 3.494003068914e-03
#   2 SNES Function norm 1.032750726275e-04
#   3 SNES Function norm 2.158632524487e-07
#   4 SNES Function norm 1.116723881690e-12
#   5 SNES Function norm 1.324876414034e-16
# Step 29: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.199951655589e-04
#   1 SNES Function norm 3.318647473150e-03
#   2 SNES Function norm 8.471260084070e-05
#   3 SNES Function norm 1.315659600450e-07
#   4 SNES Function norm 4.571668253815e-13
#   5 SNES Function norm 1.337029535191e-16
# Step 30: converged_reason=4 num_iterations=5
#   0 SNES Function norm 2.045684976838e-04
#   1 SNES Function norm 2.548717407183e-03
#   2 SNES Function norm 4.194638157378e-05
#   3 SNES Function norm 2.799586475581e-08
#   4 SNES Function norm 1.600784983685e-14
#   5 SNES Function norm 1.302411343408e-16
# Step 31: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.905894059089e-04
#   1 SNES Function norm 2.118255651187e-03
#   2 SNES Function norm 2.772464712736e-05
#   3 SNES Function norm 1.077347532791e-08
#   4 SNES Function norm 2.074821511891e-15
#   5 SNES Function norm 1.294303235372e-16
# Step 32: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.943537217062e-04
#   1 SNES Function norm 4.033940679224e-03
#   2 SNES Function norm 2.383900376099e-04
#   3 SNES Function norm 1.836950869382e-06
#   4 SNES Function norm 1.258059025569e-10
#   5 SNES Function norm 1.332173472499e-16
#   6 SNES Function norm 1.314185810355e-16
# Step 33: converged_reason=4 num_iterations=6
#   0 SNES Function norm 2.028869211957e-04
#   1 SNES Function norm 6.660646116407e-03
#   2 SNES Function norm 5.119273024803e-04
#   3 SNES Function norm 5.155175187724e-06
#   4 SNES Function norm 5.838342170204e-10
#   5 SNES Function norm 1.336884729748e-16
#   6 SNES Function norm 1.316504034299e-16
# Step 34: converged_reason=4 num_iterations=6
#   0 SNES Function norm 1.677890593312e-04
#   1 SNES Function norm 1.793237862805e-03
#   2 SNES Function norm 2.193208916548e-05
#   3 SNES Function norm 9.731147058167e-09
#   4 SNES Function norm 3.203436261488e-15
#   5 SNES Function norm 1.285597898376e-16
# Step 35: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.492293408224e-04
#   1 SNES Function norm 1.391035197519e-03
#   2 SNES Function norm 2.552895698265e-05
#   3 SNES Function norm 3.651169231812e-08
#   4 SNES Function norm 8.104643793890e-14
#   5 SNES Function norm 1.295778837983e-16
# Step 36: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.387470362509e-04
#   1 SNES Function norm 1.118557887771e-03
#   2 SNES Function norm 1.005376765966e-05
#   3 SNES Function norm 3.795753644942e-09
#   4 SNES Function norm 6.839617601360e-16
#   5 SNES Function norm 1.288283958652e-16
# Step 37: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.311757388249e-04
#   1 SNES Function norm 9.384720991205e-04
#   2 SNES Function norm 3.874193300375e-06
#   3 SNES Function norm 2.045378968998e-10
#   4 SNES Function norm 1.305688255019e-16
#   5 SNES Function norm 1.282982267006e-16
# Step 38: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.264343899321e-04
#   1 SNES Function norm 8.671092131360e-04
#   2 SNES Function norm 3.878277929404e-06
#   3 SNES Function norm 3.654737418541e-10
#   4 SNES Function norm 1.326589517319e-16
#   5 SNES Function norm 1.302925741008e-16
# Step 39: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.241873399754e-04
#   1 SNES Function norm 9.033545189976e-04
#   2 SNES Function norm 9.992269600927e-06
#   3 SNES Function norm 4.087614289311e-09
#   4 SNES Function norm 7.053050983186e-16
#   5 SNES Function norm 1.302228250925e-16
# Step 40: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.268082590894e-04
#   1 SNES Function norm 1.107825323379e-03
#   2 SNES Function norm 4.864272186077e-06
#   3 SNES Function norm 1.732135855605e-10
#   4 SNES Function norm 1.322198967556e-16
#   5 SNES Function norm 1.295639801038e-16
# Step 41: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.410033390240e-04
#   1 SNES Function norm 4.751044286203e-03
#   2 SNES Function norm 4.330203491268e-04
#   3 SNES Function norm 5.633995021812e-06
#   4 SNES Function norm 1.010806840178e-09
#   5 SNES Function norm 1.347750866905e-16
#   6 SNES Function norm 1.299857856225e-16
# Step 42: converged_reason=4 num_iterations=6
#   0 SNES Function norm 1.349259295136e-04
#   1 SNES Function norm 2.766624815761e-03
#   2 SNES Function norm 9.297953001152e-05
#   3 SNES Function norm 1.699418432994e-07
#   4 SNES Function norm 6.101682794754e-13
#   5 SNES Function norm 1.306929835501e-16
# Step 43: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.156286312833e-04
#   1 SNES Function norm 7.771044541344e-04
#   2 SNES Function norm 1.722036916656e-06
#   3 SNES Function norm 2.073189910592e-11
#   4 SNES Function norm 1.306629779882e-16
#   5 SNES Function norm 1.291512764905e-16
# Step 44: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.068975326941e-04
#   1 SNES Function norm 5.704638368040e-04
#   2 SNES Function norm 1.125042358805e-06
#   3 SNES Function norm 1.271997831487e-11
#   4 SNES Function norm 1.325559720737e-16
# Step 45: converged_reason=4 num_iterations=4
#   0 SNES Function norm 1.035017702431e-04
#   1 SNES Function norm 5.388330107337e-04
#   2 SNES Function norm 1.154159410660e-06
#   3 SNES Function norm 1.527093258962e-11
#   4 SNES Function norm 1.324587067343e-16
#   5 SNES Function norm 1.297407761917e-16
# Step 46: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.032938292221e-04
#   1 SNES Function norm 5.486806421642e-04
#   2 SNES Function norm 1.518572746456e-06
#   3 SNES Function norm 6.641395956931e-11
#   4 SNES Function norm 1.323572467338e-16
#   5 SNES Function norm 1.300736579718e-16
# Step 47: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.065370975630e-04
#   1 SNES Function norm 6.529417551212e-04
#   2 SNES Function norm 3.498010158760e-06
#   3 SNES Function norm 7.157855189581e-10
#   4 SNES Function norm 1.486597216731e-16
#   5 SNES Function norm 1.289818659833e-16
# Step 48: converged_reason=4 num_iterations=5
#   0 SNES Function norm 1.147271125338e-04
#   1 SNES Function norm 1.235327189391e-03
#   2 SNES Function norm 3.171847065529e-05
#   3 SNES Function norm 3.738545850888e-08
#   4 SNES Function norm 5.405213201199e-14
#   5 SNES Function norm 1.297372856235e-16
# Step 49: converged_reason=4 num_iterations=5

# %% [markdown]
# Update plot

# %%
if have_pyvista:
    grid.point_data["c"] = u.x.array[dofs].real
    screenshot = out_folder / "ch.png" if pv.OFF_SCREEN else None
    pv.plot(grid, show_edges=True, screenshot=screenshot)
# Out:
# /home/kamila/miniconda3/envs/fenicsx-env/lib/python3.11/site-packages/pyvista/jupyter/notebook.py:56: UserWarning: Failed to use notebook backend:
#
# cannot import name 'vtk' from 'trame.widgets' (/home/kamila/miniconda3/envs/fenicsx-env/lib/python3.11/site-packages/trame/widgets/__init__.py)
#
# Falling back to a static output.
#   warnings.warn(
# <PIL.Image.Image image mode=RGB size=1024x768>
